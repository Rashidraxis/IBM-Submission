# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>Rashid Faruqui</strong>

# %% [markdown]
# Data Scientist

# %% [markdown]
# <em>I am interested in data science because it the most trending engineering field currently.</em>

# %% [markdown]
# <h3>My code is supposed to convert a string in number format according to ascii code</h3>

# %%
s = "RASHID"
res = ""

for x in s:
    res += str(ord(x))
    
print(res)
# Out:
# 826583727368

# %% [markdown]
# | Alphabet | Number |
# | --- | --- |
# | R | 82 |
# | A | 65 |
# | S | 83 |

# %% [markdown]
# <ul>
# <li>Enjoy the Video</li>
# </ul>

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=eBGIQ7ZuuiU">Watch It</a>
